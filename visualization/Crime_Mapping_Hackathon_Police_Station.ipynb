# %%
import folium
from folium import plugins
import ipywidgets
import geocoder
import geopy
import pandas as pd
import numpy as np
#from vega_datasets import data as vds
import plotly.express as px
import json
import base64
from folium import IFrame

# %%
# !pip install folium
# !pip install ipywidgets
# !pip install geocoder
# !pip install geopy
# !pip install pandas
# !pip install numpy
# !pip install plotly
# !pip install json
# !pip install base64

# %%
ut_map = folium.Map(location = [30.316496, 78.032188], zoom_start = 12, control_scale = True)
ut_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_37740317ad275cdf3daeb7e93a312745 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_37740317ad275cdf3daeb7e93a312745&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_37740317ad275cdf3daeb7e93a312745 = L.map(
#                 &quot;map_37740317ad275cdf3daeb7e93a312745&quot;,
#                 {
#                     center: [30.316496, 78.032188],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_37740317ad275cdf3daeb7e93a312745);
#
#
#
#
#
#             var tile_layer_cb5255e81cd7e5ba7b3ff50d8e1892fc = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_37740317ad275cdf3daeb7e93a312745);
#
# &lt;/script&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
ut_map_lc = ut_map

folium.raster_layers.TileLayer('Open Street Map').add_to(ut_map_lc)
folium.raster_layers.TileLayer('Stamen Terrain').add_to(ut_map_lc)
folium.raster_layers.TileLayer('Stamen Toner').add_to(ut_map_lc)
folium.raster_layers.TileLayer('Stamen Watercolor').add_to(ut_map_lc)
folium.raster_layers.TileLayer('CartoDB Positron').add_to(ut_map_lc)
folium.raster_layers.TileLayer('CartoDB Dark_Matter').add_to(ut_map_lc)

folium.LayerControl().add_to(ut_map_lc)

ut_map_lc
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_4bfb7f1d55a83d1f2c2381369ee0f09b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_4bfb7f1d55a83d1f2c2381369ee0f09b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_4bfb7f1d55a83d1f2c2381369ee0f09b = L.map(
#                 &quot;map_4bfb7f1d55a83d1f2c2381369ee0f09b&quot;,
#                 {
#                     center: [30.316496, 78.032188],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_4bfb7f1d55a83d1f2c2381369ee0f09b);
#
#
#
#
#
#             var tile_layer_30c6c7035573f05a07b333455a8cec11 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_4bfb7f1d55a83d1f2c2381369ee0f09b);
#
#
#             var tile_layer_6ecbc3b688fcab7b7c83b1228fb4e347 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_4bfb7f1d55a83d1f2c2381369ee0f09b);
#
#
#             var tile_layer_ab9ec3625805924b41e7ece421474884 = L.tileLayer(
#                 &quot;https://stamen-tiles-{s}.a.ssl.fastly.net/terrain/{z}/{x}/{y}.jpg&quot;,
#                 {&quot;attribution&quot;: &quot;Map tiles by \u003ca href=\&quot;http://stamen.com\&quot;\u003eStamen Design\u003c/a\u003e, under \u003ca href=\&quot;http://creativecommons.org/licenses/by/3.0\&quot;\u003eCC BY 3.0\u003c/a\u003e. Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://creativecommons.org/licenses/by-sa/3.0\&quot;\u003eCC BY SA\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_4bfb7f1d55a83d1f2c2381369ee0f09b);
#
#
#             var tile_layer_a36b01221168accfec3da24d97acde9a = L.tileLayer(
#                 &quot;https://stamen-tiles-{s}.a.ssl.fastly.net/toner/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Map tiles by \u003ca href=\&quot;http://stamen.com\&quot;\u003eStamen Design\u003c/a\u003e, under \u003ca href=\&quot;http://creativecommons.org/licenses/by/3.0\&quot;\u003eCC BY 3.0\u003c/a\u003e. Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_4bfb7f1d55a83d1f2c2381369ee0f09b);
#
#
#             var tile_layer_46eb3e66454b8eba370794fc1a02f71d = L.tileLayer(
#                 &quot;https://stamen-tiles-{s}.a.ssl.fastly.net/watercolor/{z}/{x}/{y}.jpg&quot;,
#                 {&quot;attribution&quot;: &quot;Map tiles by \u003ca href=\&quot;http://stamen.com\&quot;\u003eStamen Design\u003c/a\u003e, under \u003ca href=\&quot;http://creativecommons.org/licenses/by/3.0\&quot;\u003eCC BY 3.0\u003c/a\u003e. Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://creativecommons.org/licenses/by-sa/3.0\&quot;\u003eCC BY SA\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_4bfb7f1d55a83d1f2c2381369ee0f09b);
#
#
#             var tile_layer_8f4baa4b3b5fdacc6a1aae685333a73a = L.tileLayer(
#                 &quot;https://cartodb-basemaps-{s}.global.ssl.fastly.net/light_all/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;http://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e, CartoDB \u003ca href =\&quot;http://cartodb.com/attributions\&quot;\u003eattributions\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &q

# %%
minimap = plugins.MiniMap(toggle_display = True)

ut_map_lc.add_child(minimap)

#plugins.ScrollZoomToggler().add_to(ut_map_lc)

plugins.Fullscreen(position='bottomright').add_to(ut_map_lc)
plugins.Draw(export = True).add_to(ut_map_lc)

ut_map_lc
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\HP\Documents\Open\OSC-Crime-Analysis-and-Prediction\visualization\Crime_Mapping_Hackathon_Police_Station.ipynb Cell 5' in <cell line: 3>()
#       <a href='vscode-notebook-cell:/c%3A/Users/HP/Documents/Open/OSC-Crime-Analysis-and-Prediction/visualization/Crime_Mapping_Hackathon_Police_Station.ipynb#ch0000004?line=0'>1</a> minimap = plugins.MiniMap(toggle_display = True)
# ----> <a href='vscode-notebook-cell:/c%3A/Users/HP/Documents/Open/OSC-Crime-Analysis-and-Prediction/visualization/Crime_Mapping_Hackathon_Police_Station.ipynb#ch0000004?line=2'>3</a> ut_map_lc.add_child(minimap)
#       <a href='vscode-notebook-cell:/c%3A/Users/HP/Documents/Open/OSC-Crime-Analysis-and-Prediction/visualization/Crime_Mapping_Hackathon_Police_Station.ipynb#ch0000004?line=4'>5</a> #plugins.ScrollZoomToggler().add_to(ut_map_lc)
#       <a href='vscode-notebook-cell:/c%3A/Users/HP/Documents/Open/OSC-Crime-Analysis-and-Prediction/visualization/Crime_Mapping_Hackathon_Police_Station.ipynb#ch0000004?line=6'>7</a> plugins.Fullscreen(position='bottomright').add_to(ut_map_lc)
#
# NameError: name 'ut_map_lc' is not defined

# %%
criminal_csv = pd.read_csv("criminal_data.csv") # read the data
criminal_csv.drop('0', axis=1, inplace=True)
criminal_csv.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\Users\HP\Documents\Open\OSC-Crime-Analysis-and-Prediction\visualization\Crime_Mapping_Hackathon_Police_Station.ipynb Cell 6' in <cell line: 2>()
#       <a href='vscode-notebook-cell:/c%3A/Users/HP/Documents/Open/OSC-Crime-Analysis-and-Prediction/visualization/Crime_Mapping_Hackathon_Police_Station.ipynb#ch0000005?line=0'>1</a> criminal_csv = pd.read_csv("criminal_data.csv") # read the data
# ----> <a href='vscode-notebook-cell:/c%3A/Users/HP/Documents/Open/OSC-Crime-Analysis-and-Prediction/visualization/Crime_Mapping_Hackathon_Police_Station.ipynb#ch0000005?line=1'>2</a> criminal_csv.drop('0', axis=1, inplace=True)
#       <a href='vscode-notebook-cell:/c%3A/Users/HP/Documents/Open/OSC-Crime-Analysis-and-Prediction/visualization/Crime_Mapping_Hackathon_Police_Station.ipynb#ch0000005?line=2'>3</a> criminal_csv.head()
#
# File c:\Users\HP\anaconda3\lib\site-packages\pandas\core\frame.py:4308, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4178 def drop(
#    4179     self,
#    4180     labels=None,
#    (...)
#    4186     errors="raise",
#    4187 ):
#    4188     """
#    4189     Drop specified labels from rows or columns.
#    4190
#    (...)
#    4306             weight  1.0     0.8
#    4307     """
# -> 4308     return super().drop(
#    4309         labels=labels,
#    4310         axis=axis,
#    4311         index=index,
#    4312         columns=columns,
#    4313         level=level,
#    4314         inplace=inplace,
#    4315         errors=errors,
#    4316     )
#
# File c:\Users\HP\anaconda3\lib\site-packages\pandas\core\generic.py:4153, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4151 for axis, labels in axes.items():
#    4152     if labels is not None:
# -> 4153         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4155 if inplace:
#    4156     self._update_inplace(obj)
#
# File c:\Users\HP\anaconda3\lib\site-packages\pandas\core\generic.py:4188, in NDFrame._drop_axis(self, labels, axis, level, errors)
#    4186         new_axis = axis.drop(labels, level=level, errors=errors)
#    4187     else:
# -> 4188         new_axis = axis.drop(labels, errors=errors)
#    4189     result = self.reindex(**{axis_name: new_axis})
#    4191 # Case for non-unique axis
#    4192 else:
#
# File c:\Users\HP\anaconda3\lib\site-packages\pandas\core\indexes\base.py:5591, in Index.drop(self, labels, errors)
#    5589 if mask.any():
#    5590     if errors != "ignore":
# -> 5591         raise KeyError(f"{labels[mask]} not found in axis")
#    5592     indexer = indexer[~mask]
#    5593 return self.delete(indexer)
#
# KeyError: "['0'] not found in axis"

# %%
df_criminal_org = pd.DataFrame(criminal_csv) # transfer to dataframe
df_criminal_org.dropna(inplace=True)
df_criminal_org
# Out:
#        Unnamed: 0 Incident Datetime   Report Datetime  Incident ID Penal Code  \
# 0               0  05-03-2019 21:00  07-03-2019 12:54       778087        378
# 1               1  22-12-2018 12:00  26-12-2018 14:29       752469        378
# 2               2  24-08-2018 17:30  24-08-2018 19:35       706753        378
# 3               3  20-10-2018 15:10  20-10-2018 15:10       728264        421
# 4               4  05-06-2019 00:36  05-06-2019 00:37       808230        393
# ...           ...               ...               ...          ...        ...
# 49995       49995  04-03-2020 16:00  14-03-2020 22:02       912879        425
# 49996       49996  24-10-2019 13:40  24-10-2019 13:49       862270        378
# 49997       49997  20-07-2019 14:00  25-07-2019 23:00       828068        378
# 49998       49998  03-07-2019 18:00  10-09-2019 15:35       845358        378
# 49999       49999  09-02-2020 10:31  09-02-2020 14:09       900880        279
#
#                   Crimes                   Incident Description  \
# 0                  Theft        Theft, Other Property, $50-$200
# 1                  Theft            Vehicle, Stolen, Motorcycle
# 2                  Theft  Theft, From Locked Vehicle, $200-$950
# 3                  Other                       Probation Search
# 4                  Other                    Air Gun, Possession
# ...                  ...                                    ...
# 49995      Lost Property                          Lost Property
# 49996              Theft         Theft from Merchant or Library
# 49997              Theft        Theft, Other Property, $50-$200
# 49998              Theft           Theft, Other Property, >$950
# 49999  Recovered Vehicle               Vehicle, Recovered, Auto
#
#                  Resolution Police District   Latitude   Longitude
# 0            Open or Active        Dehradun  37.779992 -122.413487
# 1            Open or Active        Northern  37.775787 -122.427819
# 2            Open or Active       Ingleside  37.723944 -122.422830
# 3      Cite or Arrest Adult        Southern  37.775161 -122.403635
# 4      Cite or Arrest Adult         Central  37.802755 -122.413623
# ...                     ...             ...        ...         ...
# 49995        Open or Active        Dehradun  37.782231 -122.410292
# 49996        Open or Active            Park  37.769798 -122.448579
# 49997        Open or Active         Central  37.788721 -122.402066
# 49998        Open or Active        Northern  37.786359 -122.419833
# 49999        Open or Active         Bayview  37.734277 -122.448893
#
# [47312 rows x 11 columns]

# %%
df_criminal_org.apply(lambda row : folium.Marker(location = [row['Latitudes'], row['Longitudes']],
                                            popup = row['Police Stations Under Dehradun District of Uttrakhand'] + ' ' + row['Details'],
                                            icon = folium.Icon(icon = 'star empty', color = 'blue', prefix = 'glyphicon')).add_to(ut_map_lc), axis = 1)


ut_map_lc
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\HP\anaconda3\lib\site-packages\pandas\core\indexes\base.py:3080, in Index.get_loc(self, key, method, tolerance)
#    3079 try:
# -> 3080     return self._engine.get_loc(casted_key)
#    3081 except KeyError as err:
#
# File pandas\_libs\index.pyx:70, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\index.pyx:101, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:4554, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:4562, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Latitudes'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# c:\Users\HP\Documents\Open\OSC-Crime-Analysis-and-Prediction\visualization\Crime_Mapping_Hackathon_Police_Station.ipynb Cell 11' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/HP/Documents/Open/OSC-Crime-Analysis-and-Prediction/visualization/Crime_Mapping_Hackathon_Police_Station.ipynb#ch0000010?line=0'>1</a> df_criminal_org.apply(lambda row : folium.Marker(location = [row['Latitudes'], row['Longitudes']],
#       <a href='vscode-notebook-cell:/c%3A/Users/HP/Documents/Open/OSC-Crime-Analysis-and-Prediction/visualization/Crime_Mapping_Hackathon_Police_Station.ipynb#ch0000010?line=1'>2</a>                                             popup = row['Police Stations Under Dehradun District of Uttrakhand'] + ' ' + row['Details'],
#       <a href='vscode-notebook-cell:/c%3A/Users/HP/Documents/Open/OSC-Crime-Analysis-and-Prediction/visualization/Crime_Mapping_Hackathon_Police_Station.ipynb#ch0000010?line=2'>3</a>                                             icon = folium.Icon(icon = 'star empty', color = 'blue', prefix = 'glyphicon')).add_to(ut_map_lc), axis = 1)
#       <a href='vscode-notebook-cell:/c%3A/Users/HP/Documents/Open/OSC-Crime-Analysis-and-Prediction/visualization/Crime_Mapping_Hackathon_Police_Station.ipynb#ch0000010?line=5'>6</a> ut_map_lc
#
# File c:\Users\HP\anaconda3\lib\site-packages\pandas\core\frame.py:7768, in DataFrame.apply(self, func, axis, raw, result_type, args, **kwds)
#    7757 from pandas.core.apply import frame_apply
#    7759 op = frame_apply(
#    7760     self,
#    7761     func=func,
#    (...)
#    7766     kwds=kwds,
#    7767 )
# -> 7768 return op.get_result()
#
# File c:\Users\HP\anaconda3\lib\site-packages\pandas\core\apply.py:185, in FrameApply.get_result(self)
#     182 elif self.raw:
#     183     return self.apply_raw()
# --> 185 return self.apply_standard()
#
# File c:\Users\HP\anaconda3\lib\site-packages\pandas\core\apply.py:276, in FrameApply.apply_standard(self)
#     275 def apply_standard(self):
# --> 276     results, res_index = self.apply_series_generator()
#     278     # wrap results
#     279     return self.wrap_results(results, res_index)
#
# File c:\Users\HP\anaconda3\lib\site-packages\pandas\core\apply.py:290, in FrameApply.apply_series_generator(self)
#     287 with option_context("mode.chained_assignment", None):
#     288     for i, v in enumerate(series_gen):
#     289         # ignore SettingWithCopy here in case the user mutates
# --> 290         results[i] = self.f(v)
#     291         if isinstance(results[i], ABCSeries):
#     292             # If we have a view on v, we need to make a copy because
#     293             #  series_generator will swap out the underlying data
#     294             results[i] = results[i].copy(deep=False)
#
# c:\Users\HP\Documents\Open\OSC-Crime-Analysis-and-Prediction\visualization\Crime_Mapping_Hackathon_Police_Station.ipynb Cell 11' in <lambda>(row)
# ----> <a href='vscode-notebook-cell:/c%3A/Users/HP/Documents/Open/OSC-Crime-Analysis-and-Prediction/visualization/Crime_Mapping_Hackathon_Police_Station.ipynb#ch0000010?line=0'>1</a> df_criminal_org.apply(lambda row : folium.Marker(location = [row['Latitudes'], row['Longitudes']],
#       <a href='vscode-notebook-cell:/c%3A/Users/HP/Documents/Open/OSC-Crime-Analysis-and-Prediction/visualization/Crime_Mapping_Hackathon_Police_Station.ipynb#ch0000010?line=1'>2</a>                                             popup = row['Police Stations Under Dehradun District of Uttrakhand'] + ' ' + row['Details'],
#       <a href='vscode-notebook-cell:/c%3A/Users/HP/Documents/Open/OSC-Crime-Analysis-and-Prediction/visualization/Crime_Mapping_Hackathon_Police_Station.ipynb#ch0000010?line=2'>3</a>                                             icon = folium.Icon(icon = 'star empty', color = 'blue', prefix = 'glyphicon')).add_to(ut_map_lc), axis = 1)
#       <a href='vscode-notebook-cell:/c%3A/Users/HP/Documents/Open/OSC-Crime-Analysis-and-Prediction/visualization/Crime_Mapping_Hackathon_Police_Station.ipynb#ch0000010?line=5'>6</a> ut_map_lc
#
# File c:\Users\HP\anaconda3\lib\site-packages\pandas\core\series.py:853, in Series.__getitem__(self, key)
#     850     return self._values[key]
#     852 elif key_is_scalar:
# --> 853     return self._get_value(key)
#     855 if is_hashable(key):
#     856     # Otherwise index.get_value will raise InvalidIndexError
#     857     try:
#     858         # For labels that don't resolve as scalars like tuples and frozensets
#
# File c:\Users\HP\anaconda3\lib\site-packages\pandas\core\series.py:961, in Series._get_value(self, label, takeable)
#     958     return self._values[label]
#     960 # Similar to Index.get_value, but we do not fall back to positional
# --> 961 loc = self.index.get_loc(label)
#     962 return self.index._get_values_for_loc(self, loc, label)
#
# File c:\Users\HP\anaconda3\lib\site-packages\pandas\core\indexes\base.py:3082, in Index.get_loc(self, key, method, tolerance)
#    3080         return self._engine.get_loc(casted_key)
#    3081     except KeyError as err:
# -> 3082         raise KeyError(key) from err
#    3084 if tolerance is not None:
#    3085     tolerance = self._convert_tolerance(tolerance, np.asarray(key))
#
# KeyError: 'Latitudes'

# %%
ut_map_lc.add_child(folium.LatLngPopup())


measuring_dist = plugins.MeasureControl(position = 'topleft',
                                       active_color = 'indigo',
                                       completed_color = 'red',
                                       primary_length_unit = 'miles')

ut_map_lc.add_child(measuring_dist)
ut_map_lc
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\HP\Documents\Open\OSC-Crime-Analysis-and-Prediction\visualization\Crime_Mapping_Hackathon_Police_Station.ipynb Cell 12' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/HP/Documents/Open/OSC-Crime-Analysis-and-Prediction/visualization/Crime_Mapping_Hackathon_Police_Station.ipynb#ch0000011?line=0'>1</a> ut_map_lc.add_child(folium.LatLngPopup())
#       <a href='vscode-notebook-cell:/c%3A/Users/HP/Documents/Open/OSC-Crime-Analysis-and-Prediction/visualization/Crime_Mapping_Hackathon_Police_Station.ipynb#ch0000011?line=3'>4</a> measuring_dist = plugins.MeasureControl(position = 'topleft',
#       <a href='vscode-notebook-cell:/c%3A/Users/HP/Documents/Open/OSC-Crime-Analysis-and-Prediction/visualization/Crime_Mapping_Hackathon_Police_Station.ipynb#ch0000011?line=4'>5</a>                                        active_color = 'indigo',
#       <a href='vscode-notebook-cell:/c%3A/Users/HP/Documents/Open/OSC-Crime-Analysis-and-Prediction/visualization/Crime_Mapping_Hackathon_Police_Station.ipynb#ch0000011?line=5'>6</a>                                        completed_color = 'red',
#       <a href='vscode-notebook-cell:/c%3A/Users/HP/Documents/Open/OSC-Crime-Analysis-and-Prediction/visualization/Crime_Mapping_Hackathon_Police_Station.ipynb#ch0000011?line=6'>7</a>                                        primary_length_unit = 'miles')
#       <a href='vscode-notebook-cell:/c%3A/Users/HP/Documents/Open/OSC-Crime-Analysis-and-Prediction/visualization/Crime_Mapping_Hackathon_Police_Station.ipynb#ch0000011?line=8'>9</a> ut_map_lc.add_child(measuring_dist)
#
# NameError: name 'ut_map_lc' is not defined

# %%
address_text_box = ipywidgets.Text(value='', placeholder='type here', description='address:')

# widget function
def plot_locations(address):
    # location address
    location = geocoder.osm(address)
    
    # latitude and longitude of location
    latlng = [location.lat, location.lng]
    
    # create map
    plot_locations_map = folium.Map(location=[30.316496, 78.032188], zoom_start=12)
    
    # marker
    folium.Marker(latlng, popup=str(address), tooltip='click').add_to(plot_locations_map)
    
    # display map
    display(plot_locations_map)
    
# interaction between widget and function    
ipywidgets.interact_manual(plot_locations, address=address_text_box)
# Out:
# interactive(children=(Text(value='', description='address:', placeholder='type here'), Button(description='Run…
# <function __main__.plot_locations(address)>

# %%
ut_map_1 = folium.Map(location = [30.066753, 79.019300], zoom_start = 8, control_scale = True)

AL = geocoder.osm('Almora, Uttarakhand')
BA = geocoder.osm('Bageshwar, Uttarakhand')
CL = geocoder.osm('Chamoli, Uttarakhand')
CP = geocoder.osm('Champawat, Uttarakhand')
DD = geocoder.osm('Dehradun, Uttarakhand')
HA = geocoder.osm('Haridwar, Uttarakhand')
NA = geocoder.osm('Nainital, Uttarakhand')
PG = geocoder.osm('Pauri Garhwal, Uttarakhand')
PI = geocoder.osm('Pithoragarh, Uttarakhand')
RP = geocoder.osm('Rudraprayag, Uttarakhand')
TG = geocoder.osm('Tehri Garhwal, Uttarakhand')
US = geocoder.osm('Udham Singh Nagar, Uttarakhand')
UT = geocoder.osm('Uttarkashi, Uttarakhand')

#lat,lon
AL_latlon = [AL.lat, AL.lng, 9999999/1000]
BA_latlon = [BA.lat, BA.lng, 8888888/1000]
CL_latlon = [CL.lat, CL.lng, 7777777/1000]
CP_latlon = [CP.lat, CP.lng, 6666666/1000]
DD_latlon = [DD.lat, DD.lng, 5555555/1000]
HA_latlon = [HA.lat, HA.lng, 4444444/1000]
NA_latlon = [NA.lat, NA.lng, 3333333/1000]
PG_latlon = [PG.lat, PG.lng, 2222222/1000]
PI_latlon = [PI.lat, PI.lng, 1111111/1000]
RP_latlon = [RP.lat, RP.lng, 999999/1000]
TG_latlon = [TG.lat, TG.lng, 888888/1000]
US_latlon = [US.lat, US.lng, 777777/1000]
UT_latlon = [UT.lat, UT.lng, 666666/1000]

districts_ut = [AL_latlon, BA_latlon, CL_latlon, CP_latlon, DD_latlon, HA_latlon, NA_latlon, PG_latlon, PI_latlon,
               RP_latlon, TG_latlon, US_latlon, UT_latlon]
plugins.HeatMap(districts_ut, radius = 50).add_to(ut_map_1)

ut_map_1
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_cf38231e6d9facb154704a55c8fc985c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium@master/folium/templates/leaflet_heat.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_cf38231e6d9facb154704a55c8fc985c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_cf38231e6d9facb154704a55c8fc985c = L.map(
#                 &quot;map_cf38231e6d9facb154704a55c8fc985c&quot;,
#                 {
#                     center: [30.066753, 79.0193],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 8,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_cf38231e6d9facb154704a55c8fc985c);
#
#
#
#
#
#             var tile_layer_d3b3c553bc72c7a459e686bfbdfedd7f = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_cf38231e6d9facb154704a55c8fc985c);
#
#
#             var heat_map_8d78d8cf0b8d90c4e7b1b4ad3a0a048b = L.heatLayer(
#                 [[29.703094999999998, 79.43317023326716, 9999.999], [30.0084975, 79.93004575415591, 8888.888], [30.5, 79.5, 7777.777], [29.23631315, 80.10172076512075, 6666.666], [30.3255646, 78.0436813, 5555.555], [29.91235135, 78.00871782398349, 4444.444], [29.29478295, 79.41548093726253, 3333.333], [29.84591115, 78.70766746320547, 2222.222], [29.585871, 80.215167, 1111.111], [30.3009965, 79.06287964782695, 999.999], [30.5, 78.666667, 888.888], [29.048098799999998, 79.4313133223357, 777.777], [30.7291049, 78.4403495, 666.666]],
#                 {&quot;blur&quot;: 15, &quot;maxZoom&quot;: 18, &quot;minOpacity&quot;: 0.5, &quot;radius&quot;: 50}
#             ).addTo(map_cf38231e6d9facb154704a55c8fc985c);
#
# &lt;/script&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
ut_map_test = folium.Map(location = [30.316496, 78.032188], zoom_start = 12, control_scale = True)
encoded = base64.b64encode(open('mypict.jpg', 'rb').read())
html = '<img src="data:image/png;base64,{}">'.format
iframe = IFrame(html(encoded.decode('UTF-8')), width=400, height=350)
popup = folium.Popup(iframe, max_width=400)
x = folium.Marker(location = [30.216496, 78.132188],tooltip=html, popup = popup,
                                            icon = folium.Icon(icon = 'star empty', color = 'green', prefix = 'glyphicon'))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# c:\Users\HP\Documents\Open\OSC-Crime-Analysis-and-Prediction\visualization\Crime_Mapping_Hackathon_Police_Station.ipynb Cell 21' in <cell line: 2>()
#       <a href='vscode-notebook-cell:/c%3A/Users/HP/Documents/Open/OSC-Crime-Analysis-and-Prediction/visualization/Crime_Mapping_Hackathon_Police_Station.ipynb#ch0000020?line=0'>1</a> ut_map_test = folium.Map(location = [30.316496, 78.032188], zoom_start = 12, control_scale = True)
# ----> <a href='vscode-notebook-cell:/c%3A/Users/HP/Documents/Open/OSC-Crime-Analysis-and-Prediction/visualization/Crime_Mapping_Hackathon_Police_Station.ipynb#ch0000020?line=1'>2</a> encoded = base64.b64encode(open('mypict.jpg', 'rb').read())
#       <a href='vscode-notebook-cell:/c%3A/Users/HP/Documents/Open/OSC-Crime-Analysis-and-Prediction/visualization/Crime_Mapping_Hackathon_Police_Station.ipynb#ch0000020?line=2'>3</a> html = '<img src="data:image/png;base64,{}">'.format
#       <a href='vscode-notebook-cell:/c%3A/Users/HP/Documents/Open/OSC-Crime-Analysis-and-Prediction/visualization/Crime_Mapping_Hackathon_Police_Station.ipynb#ch0000020?line=3'>4</a> iframe = IFrame(html(encoded.decode('UTF-8')), width=400, height=350)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'mypict.jpg'

# %%
x.add_to(ut_map_test)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\HP\Documents\Open\OSC-Crime-Analysis-and-Prediction\visualization\Crime_Mapping_Hackathon_Police_Station.ipynb Cell 22' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/HP/Documents/Open/OSC-Crime-Analysis-and-Prediction/visualization/Crime_Mapping_Hackathon_Police_Station.ipynb#ch0000021?line=0'>1</a> x.add_to(ut_map_test)
#
# NameError: name 'x' is not defined

# %%
ut_map_test
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_2622b0ffbd503a1e14a1fd85e7cd8d20 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_2622b0ffbd503a1e14a1fd85e7cd8d20&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_2622b0ffbd503a1e14a1fd85e7cd8d20 = L.map(
#                 &quot;map_2622b0ffbd503a1e14a1fd85e7cd8d20&quot;,
#                 {
#                     center: [30.316496, 78.032188],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_2622b0ffbd503a1e14a1fd85e7cd8d20);
#
#
#
#
#
#             var tile_layer_3b031f665503e6fd1409f3562319e7cb = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_2622b0ffbd503a1e14a1fd85e7cd8d20);
#
#
#             var marker_7cbc3257bc7b2df8558195a73205ec24 = L.marker(
#                 [30.216496, 78.132188],
#                 {}
#             ).addTo(map_2622b0ffbd503a1e14a1fd85e7cd8d20);
#
#
#             var icon_5c762403b55770a7997cb1c931237f84 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;star empty&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_7cbc3257bc7b2df8558195a73205ec24.setIcon(icon_5c762403b55770a7997cb1c931237f84);
#
# &lt;/script&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
y = 1
if y == 1:
    x = folium.Marker(location = [30.216496, 78.132188],
                                            icon = folium.Icon(icon = 'star empty', color = 'red', prefix = 'glyphicon'))
x.add_to(ut_map_test)

# %%
ut_map_test
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_2622b0ffbd503a1e14a1fd85e7cd8d20 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_2622b0ffbd503a1e14a1fd85e7cd8d20&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_2622b0ffbd503a1e14a1fd85e7cd8d20 = L.map(
#                 &quot;map_2622b0ffbd503a1e14a1fd85e7cd8d20&quot;,
#                 {
#                     center: [30.316496, 78.032188],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_2622b0ffbd503a1e14a1fd85e7cd8d20);
#
#
#
#
#
#             var tile_layer_3b031f665503e6fd1409f3562319e7cb = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_2622b0ffbd503a1e14a1fd85e7cd8d20);
#
#
#             var marker_7cbc3257bc7b2df8558195a73205ec24 = L.marker(
#                 [30.216496, 78.132188],
#                 {}
#             ).addTo(map_2622b0ffbd503a1e14a1fd85e7cd8d20);
#
#
#             var icon_5c762403b55770a7997cb1c931237f84 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;star empty&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_7cbc3257bc7b2df8558195a73205ec24.setIcon(icon_5c762403b55770a7997cb1c931237f84);
#
# &lt;/script&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
